# %%
import pandas as pd
import numpy as np
from numpy import random
import seaborn as sns
import matplotlib 
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Cities with the Best Work-Life Balance 2022.csv')

# %%
df
# Out:
#     2022 2021          City       Country Remote Jobs Overworked Population  \
# 0      1    2          Oslo        Norway      41.72%                11.20%
# 1      2    -          Bern   Switzerland      44.86%                11.40%
# 2      3    1      Helsinki       Finland      38.92%                12.70%
# 3      4    3        Zurich   Switzerland      44.86%                11.90%
# 4      5    5    Copenhagen       Denmark      41.42%                10.50%
# ..   ...  ...           ...           ...         ...                   ...
# 95    96   49       Bangkok      Thailand      16.84%                15.10%
# 96    97   47     Sao Paulo        Brazil      25.65%                11.80%
# 97    98   50  Kuala Lumpur      Malaysia      30.70%                17.10%
# 98    99    -         Dubai           UAE      28.89%                23.40%
# 99   100    -     Cape Town  South Africa      26.06%                14.80%
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   2022                              100 non-null    int64
#  1   2021                              100 non-null    object
#  2   City                              100 non-null    object
#  3   Country                           100 non-null    object
#  4   Remote Jobs                       100 non-null    object
#  5   Overworked Population             100 non-null    object
#  6   Minimum Vacations Offered (Days)  100 non-null    int64
#  7   Vacations Taken (Days)            100 non-null    object
#  8   Unemployment                      100 non-null    float64
#  9   Multiple Jobholders               100 non-null    object
#  10  Inflation                         100 non-null    object
# ...

# %%
df.describe()
# Out:
#              2022  Minimum Vacations Offered (Days)  Unemployment  \
# count  100.000000                        100.000000    100.000000
# mean    50.500000                         14.410000     93.292000
# std     29.011492                          6.313518      5.888556
# min      1.000000                          6.000000     50.000000
# 25%     25.750000                         10.000000     92.675000
# 50%     50.500000                         10.000000     94.850000
# 75%     75.250000                         20.000000     95.950000
# max    100.000000                         30.000000    100.000000
#
#        Covid Impact  Covid Support  Healthcare  Access to Mental Healthcare  \
# count    100.000000      100.00000  100.000000                   100.000000
# mean      77.875000       84.95300   88.753000                    72.143000
# std        6.959949        6.91823    8.483537                     8.688286
# ...

# %%
df['Covid Support']=df['Covid Support'].replace('-','0')

# %%
df['Remote Jobs']=df['Remote Jobs'].replace('%','',regex=True).astype(float)

# %%
df['Overworked Population']=df['Overworked Population'].replace('%','',regex=True).astype(float)

# %%
df['Minimum Vacations Offered (Days)']=df['Minimum Vacations Offered (Days)'].replace('%','',regex=True).astype(float)

# %%
df['Vacations Taken (Days)']=df['Vacations Taken (Days)'].replace('-','0')
df['Vacations Taken (Days)']=df['Vacations Taken (Days)'].replace('%','',regex=True).astype(float)

# %%
df['Inflation']=df['Inflation'].replace('%','',regex=True).astype(float)

# %%
df['Multiple Jobholders']=df['Multiple Jobholders'].replace('%','',regex=True).astype(float)

# %%
print(df['Remote Jobs'].mean())
print(df['Remote Jobs'].std())
# Out:
# 37.8416
# 5.083965627839208

# %%
df.describe()
# Out:
#              2022  Remote Jobs  Overworked Population  \
# count  100.000000   100.000000             100.000000
# mean    50.500000    37.841600              12.645000
# std     29.011492     5.083966               1.866146
# min      1.000000    16.840000               8.600000
# 25%     25.750000    36.237500              11.875000
# 50%     50.500000    37.775000              12.500000
# 75%     75.250000    41.180000              13.200000
# max    100.000000    52.060000              23.400000
#
#        Minimum Vacations Offered (Days)  Vacations Taken (Days)  Unemployment  \
# count                        100.000000              100.000000    100.000000
# mean                          14.410000               14.647000     93.292000
# std                            6.313518                8.044641      5.888556
# min                            6.000000                0.000000     50.000000
# 25%                           10.000000                8.700000     92.675000
# ...

# %%
df1 = df.mask(df == '0', np.nan)

# %%
df1 = df.dropna()

# %%
sns.boxplot(df['Healthcare'])
# Out:
# <AxesSubplot:xlabel='Healthcare'>

# %%
#identifying the outliers
print(np.where(df['Healthcare']<75))
# Out:
# (array([53, 93, 94, 96, 97, 98, 99], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Covid Impact'])
# Out:
# <AxesSubplot:xlabel='Covid Impact'>

# %%
#identifying the outliers
print(np.where(df['Covid Impact']<60))
# Out:
# (array([99], dtype=int64),)

# %%
#identifying the outliers
print(np.where(df['Covid Impact']>95))
# Out:
# (array([98], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Covid Support'])
# Out:
# <AxesSubplot:xlabel='Covid Support'>

# %%
#identifying the outliers
print(np.where(df['Covid Support']<70))
# Out:
# (array([98], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Access to Mental Healthcare'])
# Out:
# <AxesSubplot:xlabel='Access to Mental Healthcare'>

# %%
#identifying the outliers
print(np.where(df['Access to Mental Healthcare']>95))
# Out:
# (array([92], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Inclusivity & Tolerance'])
# Out:
# <AxesSubplot:xlabel='Inclusivity & Tolerance'>

# %%
#identifying the outliers
print(np.where(df['Inclusivity & Tolerance']<78))
# Out:
# (array([13, 44, 53, 92, 95, 97, 98], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Happiness, Culture & Leisure'])
# Out:
# <AxesSubplot:xlabel='Happiness, Culture & Leisure'>

# %%
#identifying the outliers
print(np.where(df['Happiness, Culture & Leisure']<63))
# Out:
# (array([92, 93, 97, 99], dtype=int64),)

# %%
#identifying the outliers
print(np.where(df['Happiness, Culture & Leisure']>99))
# Out:
# (array([1, 5], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['City Safety'])
# Out:
# <AxesSubplot:xlabel='City Safety'>

# %%
#identifying the outliers
np.where(df['City Safety']<20)
# Out:
# (array([96, 99], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Outdoor Spaces'])
# Out:
# <AxesSubplot:xlabel='Outdoor Spaces'>

# %%
#identifying the outliers
np.where(df['Outdoor Spaces']<70)
# Out:
# (array([97, 98], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Air Quality'])
# Out:
# <AxesSubplot:xlabel='Air Quality'>

# %%
#identifying the outliers
np.where(df['Air Quality']<91)
# Out:
# (array([13, 44, 87, 90, 92, 95, 96, 97, 98], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Wellness and Fitness'])
# Out:
# <AxesSubplot:xlabel='Wellness and Fitness'>

# %%
#identifying the outliers
np.where(df['Wellness and Fitness']>80)
# Out:
# (array([21, 27, 92], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['TOTAL SCORE'])
# Out:
# <AxesSubplot:xlabel='TOTAL SCORE'>

# %%
#identifying the outliers
np.where(df['TOTAL SCORE']<70)
# Out:
# (array([96, 97, 98, 99], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Remote Jobs'])
# Out:
# <AxesSubplot:xlabel='Remote Jobs'>

# %%
np.where(df['Remote Jobs']<28)

#identifying the outliers
# Out:
# (array([93, 95, 96, 99], dtype=int64),)

# %%
#identifying the outliers
np.where(df['Remote Jobs']>45)
# Out:
# (array([40, 44, 61], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Overworked Population'])
# Out:
# <AxesSubplot:xlabel='Overworked Population'>

# %%
#identifying the outliers
np.where(df['Overworked Population']<10)
# Out:
# (array([ 7, 11, 12, 94], dtype=int64),)

# %%
#identifying the outliers
np.where(df['Overworked Population']>15)
# Out:
# (array([13, 44, 92, 93, 95, 97, 98], dtype=int64),)

# %%
#plotting a boxplot for outliers
sns.boxplot(df['Multiple Jobholders'])
# Out:
# <AxesSubplot:xlabel='Multiple Jobholders'>

# %%
#identifying the outliers
np.where(df['Multiple Jobholders']>9)
# Out:
# (array([ 0, 94, 98], dtype=int64),)

# %%
sns.lmplot(x='Covid Impact',y='Unemployment',data = df)
#it is observed that there is a direct impact of covid on employment in various cities

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
#We see high correlation between Healthcare and TotalSCORE, and Unempoyment with Covid Impact .
# Out:
# <AxesSubplot:>

# %%
df.groupby('Country')['City'].count().sort_values().plot.barh(figsize=(10,10))
plt.grid()
#It is evident that USA , Germany are the countries in which most of the cities are considered for the analysis respectively.

# %%
df.groupby('Country')['Remote Jobs'].count().sort_values().plot.barh(figsize=(10,10))
plt.grid()
#It is seen that U.S has most of the remote jobs then Germany UK,Canada and so on.

# %%
sns.scatterplot(x='Outdoor Spaces',y='Wellness and Fitness',data=df)
#Wellness and fitness of people are not highly affected by the availability of outdoor spaces.
# Out:
# <AxesSubplot:xlabel='Outdoor Spaces', ylabel='Wellness and Fitness'>

# %%
 sns.scatterplot(x="Covid Impact",y="Unemployment",hue="Covid Impact" ,data=df)
    #It is evident that covid impact has great influence on unemployement
# Out:
# <AxesSubplot:xlabel='Covid Impact', ylabel='Unemployment'>
